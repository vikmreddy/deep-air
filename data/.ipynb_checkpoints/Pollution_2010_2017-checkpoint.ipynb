# %% [markdown]
# ### Data Cleansing and Merging across 7 years
#
# ### Original data is at half to 1 hour intervals

# %%
import pandas as pd
import numpy as np

# %%
merged_final = pd.read_csv('./merged_final_single_station.csv', low_memory=False, index_col=0)

# %%
pollution_2010_2014 = pd.read_csv('./pollution.csv', index_col=0)

# %%
extra_weather = pd.read_csv('beijing_weather_2015_2017.csv', index_col=0).reset_index()

# %%
def fill_blank_spaces(extra_weather):
    extra_weather['cumulative_snow_hours'] = extra_weather['cumulative_snow_hours'].\
        apply(lambda x: np.nan if str(x) == '  ' else x)
    return extra_weather

# %%
extra_weather = fill_blank_spaces(extra_weather)

# %%
def fill_in_median_val(x, column_name, measure_by_class):
    '''Fill in a column name using the class, sex and title measures.'''
    if np.isnan(x[column_name]):
        x[column_name] = measure_by_class[x['year']]
    
    return x

def preprocess_air_pressure(df, grouped_class, column='air_pressure'):
    '''
    Fill nans with medians in air pressure, clean other data
    Median is grouped by year
    '''
    median_pressure_by_class = df.groupby([grouped_class])[column].median()
    df = df.apply(lambda x: fill_in_median_val(x, column, median_pressure_by_class), axis=1)
    return df

def fill_wind_dir_nans(df, grouped_class='year', column='wind_dir'):
    '''
    Fill nans in wind direction with median
        where the medians are taken from data grouped by year
    '''
    median_wind_dir_by_class = df.groupby([grouped_class])[column].median()
    df = df.apply(lambda x: fill_in_median_val(x, column, median_wind_dir_by_class),
                     axis=1)
    return df

def fix_snow_values(x):
    ''' 
    Mapping function that fixes snow values
    '''
    try:
        y = int(x)
    except ValueError as e:
        y = str(x)[1:]
    return y

def fill_snow_hours_nans(df, column='cumulative_snow_hours'):
    ''' 
    First, fill NaNs with zeroes. Then expand out the hours
    '''
    # fix typo values
    df_weather['cumulative_snow_hours'] = df_weather['cumulative_snow_hours'].\
        apply(lambda x: fix_snow_values(x) if type(x) != float else x)
    # fill columns
    df[column] = df[column].fillna(0)
    return df

def expand_snow_hours(df, column='cumulative_snow_hours'):
    pass

def preprocess_parsed_col(df, column='dew_point'):
    '''
    Redo parsing for dew
    '''
    df[column] = df[column].apply(lambda x: int(x) / 10)
    return df

# %% [markdown]
# ## Preprocessing

# %%
df_weather = preprocess_air_pressure(extra_weather, 'year')

# %%
df_weather = fill_wind_dir_nans(df_weather)

# %%
df_weather = fill_snow_hours_nans(df_weather)

# %%
df_weather[df_weather.cumulative_snow_hours.apply(lambda x: True if type(x) == float and 
                                       int(x) > 0 else False)]
# Out:
# Empty DataFrame
# Columns: [index, dew_point, air_temp, air_pressure, wind_dir, wind_speed, cumulative_snow_hours, cumulative_rain_hours, year, month, day, hour]
# Index: []

# %%
#df_weather = preprocess_parsed_col(df_weather)
#df_weather = preprocess_parsed_col(df_weather, column='air_pressure')
#df_weather = preprocess_parsed_col(df_weather, column='wind_speed')
#df_weather = preprocess_parsed_col(df_weather, column='air_temp')

# %%
pollution_2010_2014.groupby('wnd_dir').count()
# Out:
#          pollution    dew   temp  press  wnd_spd   snow   rain
# wnd_dir
# NE            4996   4996   4996   4996     4996   4996   4996
# NW           14130  14130  14130  14130    14130  14130  14130
# SE           15290  15290  15290  15290    15290  15290  15290
# cv            9384   9384   9384   9384     9384   9384   9384

# %%
#df_weather['cumulative_snow_hours'].apply(lambda x: x if type(x) == str else type(x))

# %%
df_weather[df_weather.cumulative_snow_hours.notnull()]['cumulative_snow_hours'].apply(
    lambda x: fix_snow_values(x))
# Out:
# 224      94
# 328       2
# 329      14
# 337      18
# 338      12
# 340       9
# 341       9
# 343      12
# 344      16
# 346      18
# 347      17
# 349      14
# 350      15
# 352      12
# 353      10
# 355       8
# 356       7
# 368      95
# 412      44
# 512      94
# 520      62
# 526      34
# 527       5
# 535      19
# 536      19
# 577      25
# 578      25
# 592      75
# 596      14
# 601      14
#          ..
# 24591    17
# 24592     2
# 24594     2
# 24595    14
# 24597    14
# 24598    14
# 24601    14
# 24606     4
# 24607     2
# 24610     2
# 24619    15
# 24621    15
# 24622    34
# 24630     2
# 24631    14
# 24634     2
# 24636     2
# 24637     2
# 24639    11
# 24640    15
# 24642    31
# 24885    24
# 24886    32
# 24946    55
# 24948    72
# 25036    95
# 25050    35
# 25123    34
# 25140    75
# 25141    85
# Name: cumulative_snow_hours, Length: 1093, dtype: object

# %%
df_weather[df_weather.cumulative_snow_hours.notnull()]
# Out:
#        index  dew_point  air_temp  air_pressure  wind_dir  wind_speed  \
# 224      523      -15.0      12.0        1016.6     290.0         8.0
# 328      766       -8.0      -5.0        1016.6     180.0         1.0
# 329      768       -9.0      -5.0        1016.6     180.0         1.0
# 337      787       -8.0      -5.0        1016.6     110.0         1.0
# 338      789       -8.0      -4.0        1016.6      60.0         2.0
# 340      794       -4.0      -1.0        1016.6     180.0         1.0
# 341      796       -4.0      -1.0        1016.6     130.0         2.0
# 343      801       -5.0       0.0        1016.6     140.0         2.0
# 344      803       -7.0       0.0        1016.6     150.0         2.0
# 346      808       -5.0      -1.0        1016.6     170.0         2.0
# 347      810       -5.0      -1.0        1016.6     150.0         1.0
# 349      815       -6.0      -4.0        1016.6      70.0         1.0
# 350      817       -7.0      -5.0        1016.6      80.0         1.0
# 352      822       -7.0      -6.0        1016.6     180.0         1.0
# 353      824       -6.0      -5.0        1016.6     180.0         1.0
# 355      829       -5.0      -5.0        1016.6     210.0         2.0
# 356      831       -6.0      -6.0        1016.6     180.0         1.0
# 368      859      -18.0       3.0        1016.6     320.0        10.0
# 412      962      -11.0       6.0        1016.6     290.0         5.0
# 512     1195      -11.0       4.0        1016.6      80.0         2.0
# 520     1214      -10.0      -3.0        1016.6     180.0         1.0
# 526     1228      -11.0      -7.0        1016.6     180.0         0.0
# 527     1230      -13.0      -9.0        1016.6     360.0         1.0
# 535     1249      -11.0       5.0        1016.6     180.0         1.0
# 536     1251      -11.0       5.0        1016.6     180.0         1.0
# 577     1347       -2.0      -1.0        1016.6     180.0         1.0
# 578     1349       -2.0       0.0        1016.6     180.0         1.0
# 592     1382       -5.0      -3.0        1016.6     180.0         0.0
# 596     1391       -7.0      -7.0        1016.6     360.0         2.0
# 601     1403       -5.0       1.0        1016.6     320.0         5.0
# ...      ...        ...       ...           ...       ...         ...
# 24591  57271        9.0       9.0        1014.4      70.0         1.0
# 24592  57273        9.0       9.0        1014.4      90.0         1.0
# 24594  57278        8.0       8.0        1014.4      80.0         1.0
# 24595  57280        8.0       9.0        1014.4     180.0         1.0
# 24597  57285       11.0      11.0        1014.4      70.0         1.0
# 24598  57287       11.0      12.0        1014.4     180.0         1.0
# 24601  57294       10.0      14.0        1014.4     180.0         1.0
# 24606  57306       10.0      11.0        1014.4      80.0         1.0
# 24607  57308        9.0       9.0        1014.4     180.0         1.0
# 24610  57315        9.0      10.0        1014.4     110.0         2.0
# 24619  57336       11.0      11.0        1014.4      70.0         1.0
# 24621  57341       11.0      13.0        1014.4     180.0         1.0
# 24622  57343       10.0      14.0        1014.4      30.0         2.0
# 24630  57362       10.0      13.0        1014.4     170.0         2.0
# 24631  57364       10.0      12.0        1014.4     170.0         2.0
# 24634  57371        9.0      10.0        1014.4     180.0         1.0
# 24636  57376        9.0       9.0        1014.4      90.0         1.0
# 24637  57378       10.0      10.0        1014.4     180.0         1.0
# 24639  57383       10.0      11.0        1014.4     180.0         1.0
# 24640  57385        9.0       9.0        1014.4     360.0         2.0
# 24642  57390       10.0      10.0        1014.4     350.0         4.0
# 24885  57955        6.0      10.0        1014.4     340.0         3.0
# 24886  57957        5.0      14.0        1014.4     360.0         2.0
# 24946  58097        7.0       8.0        1014.4     180.0         1.0
# 24948  58102        6.0      10.0        1014.4     320.0         3.0
# 25036  58307      -19.0      11.0        1014.4     290.0         9.0
# 25050  58340      -12.0       1.0        1014.4     270.0         3.0
# 25123  58510      -11.0       3.0        1014.4     320.0         6.0
# 25140  58550      -22.0      -2.0        1014.4     320.0        10.0
# 25141  58552      -22.0      -2.0        1014.4     330.0        11.0
#
#       cumulative_snow_hours  cumulative_rain_hours  year  month  day  hour
# 224                      94                   10.0  2015      1   10     8
# 328                      P2                    0.0  2015      1   14    16
# 329                      14                    0.0  2015      1   14    17
# 337                      18                    0.0  2015      1   15     1
# 338                      12                    0.0  2015      1   15     2
# 340                      09                    0.0  2015      1   15     4
# 341                      09                    0.0  2015      1   15     5
# 343                      12                    0.0  2015      1   15     7
# 344                      16                    0.0  2015      1   15     8
# 346                      18                    0.0  2015      1   15    10
# 347                      17                    0.0  2015      1   15    11
# 349                      14                    0.0  2015      1   15    13
# 350                      15                    0.0  2015      1   15    14
# 352                      12                    0.0  2015      1   15    16
# 353                      10                    0.0  2015      1   15    17
# 355                      08                    0.0  2015      1   15    19
# 356                      07                    0.0  2015      1   15    20
# 368                      95                   10.0  2015      1   16     8
# 412                      44                    0.0  2015      1   18     4
# 512                      94                    0.0  2015      1   22     8
# 520                      62                    0.0  2015      1   22    16
# 526                      34                    0.0  2015      1   22    22
# 527                      05                    0.0  2015      1   22    23
# 535                      19                    0.0  2015      1   23     7
# 536                      19                    0.0  2015      1   23     8
# 577                      25                    0.0  2015      1   25     1
# 578                      25                    0.0  2015      1   25     2
# 592                      75                    0.0  2015      1   25    16
# 596                      14                    0.0  2015      1   25    20
# 601                      14                    0.0  2015      1   26     1
# ...                     ...                    ...   ...    ...  ...   ...
# 24591                    17                    0.0  2017     10   25    19
# 24592                    P2                    0.0  2017     10   25    20
# 24594                    P2                    0.0  2017     10   25    22
# 24595                    14                    0.0  2017     10   25    23
# 24597                    14                    0.0  2017     10   26     1
# 24598                    14                    0.0  2017     10   26     2
# 24601                    14                    0.0  2017     10   26     5
# 24606                    04                    0.0  2017     10   26    10
# 24607                    P2                    0.0  2017     10   26    11
# 24610                    P2                    0.0  2017     10   26    14
# 24619                    15                    0.0  2017     10   26    23
# 24621                    15                    0.0  2017     10   27     1
# 24622                    34                    0.0  2017     10   27     2
# 24630                    02                    0.0  2017     10   27    10
# 24631                    14                    0.0  2017     10   27    11
# 24634                    P2                    0.0  2017     10   27    14
# 24636                    P2                    0.0  2017     10   27    16
# 24637                    P2                    0.0  2017     10   27    17
# 24639                    11                    0.0  2017     10   27    19
# 24640                    15                    0.0  2017     10   27    20
# 24642                    31                    0.0  2017     10   27    22
# 24885                    24                    0.0  2017     11    7     1
# 24886                    32                    0.0  2017     11    7     2
# 24946                    55                    0.0  2017     11    9    14
# 24948                    72                   10.0  2017     11    9    16
# 25036                    95                   10.0  2017     11   13     8
# 25050                    35                   10.0  2017     11   13    22
# 25123                    34                   10.0  2017     11   16    23
# 25140                    75                   10.0  2017     11   17    16
# 25141                    85                   10.0  2017     11   17    17
#
# [1093 rows x 12 columns]

# %%
# Checking if all are not null -- checks!
#df_weather[df_weather['air_pressure'].isnull()]

# %%
#extra_weather[extra_weather['air_pressure'].notnull()]

# %%
# extra_weather[extra_weather['cumulative_snow_hours'].apply(lambda x:
#                                                           True if type(x) != float else False
#                                                           )].\
#     head()

# %%
df_weather[df_weather.wind_dir.isnull()].count()
# Out:
# index                    3992
# dew_point                3992
# air_temp                 3992
# air_pressure             3992
# wind_dir                    0
# wind_speed               3992
# cumulative_snow_hours     446
# cumulative_rain_hours    3911
# year                     3992
# month                    3992
# day                      3992
# hour                     3992
# dtype: int64

# %%
# Querying for data types
# extra_weather['cumulative_snow_hours'].apply(lambda x: type(x)
#                                 )

# %%
# querying the dataframe at a particular index:
#extra_weather.iloc[9]

# %%
merged_final[merged_final['pm2.5'].apply(lambda x: True if str(x) == '89.59566' else False)]
# Out:
# Empty DataFrame
# Columns: [air_pressure, air_temp, cumulative_rain_hours, cumulative_snow_hours, date, day, dew_point, hour, month, pm2.5, wind_dir, wind_speed, year]
# Index: []

# %%
merged_final.iloc[-100:,:]
# Out:
#        air_pressure  air_temp  cumulative_rain_hours cumulative_snow_hours  \
# 68870   10253.00000       7.0                    6.0                   NaN
# 68871    2484.15968     -20.0                   10.0                   NaN
# 68872    2484.15968      10.0                   10.0                   NaN
# 68873   10254.00000      30.0                    6.0                   NaN
# 68874    2484.15968      10.0                   10.0                    35
# 68875    2484.15968      20.0                   10.0                   NaN
# 68876   10271.00000      32.0                    6.0                   NaN
# 68877    2484.15968      40.0                   10.0                   NaN
# 68878    2484.15968      40.0                   10.0                   NaN
# 68879   10262.00000      51.0                    6.0
# 68880    2484.15968      50.0                   10.0                   NaN
# 68881    2484.15968      60.0                   10.0                   NaN
# 68882   10232.00000      66.0                    6.0                   NaN
# 68883    2484.15968      60.0                   10.0                   NaN
# 68884    2484.15968      70.0                   10.0                   NaN
# 68885   10228.00000      57.0                    6.0                   NaN
# 68886    2484.15968      60.0                   10.0                   NaN
# 68887    2484.15968      50.0                   10.0                   NaN
# 68888   10237.00000       5.0                    6.0                   NaN
# 68889    2484.15968     -40.0                   10.0                   NaN
# 68890    2484.15968     -40.0                   10.0                   NaN
# 68891   10243.00000     -14.0                    6.0                   NaN
# 68892    2484.15968     -40.0                   10.0                   NaN
# 68893    2484.15968     -50.0                   10.0                   NaN
# 68894   10245.00000     -20.0                    6.0                   NaN
# 68895    2484.15968     -30.0                   10.0                   NaN
# 68896    2484.15968     -40.0                   10.0                   NaN
# 68897   10253.00000      27.0                    6.0                   NaN
# 68898    2484.15968     -60.0                   10.0                   NaN
# 68899    2484.15968     -70.0                   10.0                   NaN
# ...             ...       ...                    ...                   ...
# 68940    2484.15968     -30.0                   10.0                   NaN
# 68941    2484.15968     -10.0                   10.0                   NaN
# 68942   10208.00000     -15.0                    6.0                   NaN
# 68943    2484.15968     -30.0                   10.0                   NaN
# 68944    2484.15968     -10.0                   10.0                   NaN
# 68945   10207.00000      32.0                    6.0                   NaN
# 68946    2484.15968       0.0                   10.0                   NaN
# 68947    2484.15968      30.0                   10.0                    34
# 68948   10249.00000      50.0                    6.0
# 68949    2484.15968      50.0                   10.0                   NaN
# 68950    2484.15968      50.0                   10.0                   NaN
# 68951   10281.00000      41.0                    6.0
# 68952    2484.15968      60.0                   10.0                   NaN
# 68953    2484.15968      50.0                   10.0                   NaN
# 68954   10288.00000      45.0                    6.0
# 68955    2484.15968      60.0                   10.0                   NaN
# 68956    2484.15968      50.0                   10.0                   NaN
# 68957   10311.00000      35.0                    6.0
# 68958    2484.15968      20.0                   10.0                   NaN
# 68959    2484.15968      10.0                   10.0                   NaN
# 68960   10347.00000       5.0                    6.0                   NaN
# 68961    2484.15968     -10.0                   10.0                   NaN
# 68962    2484.15968     -20.0                   10.0                   NaN
# 68963   10375.00000     -15.0                    6.0                   NaN
# 68964    2484.15968     -20.0                   10.0                    75
# 68965    2484.15968     -20.0                   10.0                    85
# 68966   10371.00000     -27.0                    6.0                   NaN
# 68967    2484.15968     -30.0                   10.0                   NaN
# 68968    2484.15968     -30.0                   10.0                   NaN
# 68969   10366.00000     -29.0                    6.0                   NaN
#
#              date  day  dew_point  hour  month     pm2.5 wind_dir  wind_speed  \
# 68870  2017-11-13   13       -134    18     11  89.59566    360.0         0.0
# 68871  2017-11-13   13       -120    19     11  89.59566    340.0        30.0
# 68872  2017-11-13   13       -140    20     11  89.59566    280.0        30.0
# 68873  2017-11-13   13       -133    21     11  89.59566    340.0        20.0
# 68874  2017-11-13   13       -120    22     11  89.59566    270.0        30.0
# 68875  2017-11-13   13       -130    23     11  89.59566    290.0        50.0
# 68876  2017-11-14   14       -159     0     11  89.59566     20.0        30.0
# 68877  2017-11-14   14       -170     1     11  89.59566    300.0        80.0
# 68878  2017-11-14   14       -180     2     11  89.59566    300.0        80.0
# 68879  2017-11-14   14       -194     3     11  89.59566    360.0        50.0
# 68880  2017-11-14   14       -210     4     11  89.59566    300.0        90.0
# 68881  2017-11-14   14       -210     5     11  89.59566    290.0        70.0
# 68882  2017-11-14   14       -199     6     11  89.59566    360.0        40.0
# 68883  2017-11-14   14       -210     7     11  89.59566    290.0        80.0
# 68884  2017-11-14   14       -220     8     11  89.59566    290.0        80.0
# 68885  2017-11-14   14       -205     9     11  89.59566    340.0        20.0
# 68886  2017-11-14   14       -210    10     11  89.59566    310.0        50.0
# 68887  2017-11-14   14       -220    11     11  89.59566    300.0        40.0
# 68888  2017-11-14   14       -133    12     11  89.59566    360.0         0.0
# 68889  2017-11-14   14       -110    13     11  89.59566     90.0        10.0
# 68890  2017-11-14   14       -100    14     11  89.59566    160.0        20.0
# 68891  2017-11-14   14       -105    15     11  89.59566    360.0         0.0
# 68892  2017-11-14   14       -100    16     11  89.59566      NaN        10.0
# 68893  2017-11-14   14       -110    17     11  89.59566    360.0        10.0
# 68894  2017-11-14   14        -96    18     11  89.59566    360.0         0.0
# 68895  2017-11-14   14       -120    19     11  89.59566    340.0        20.0
# 68896  2017-11-14   14       -110    20     11  89.59566    340.0        20.0
# 68897  2017-11-14   14       9999    21     11  89.59566    290.0        30.0
# 68898  2017-11-14   14       -100    22     11  89.59566      NaN        10.0
# 68899  2017-11-14   14       -110    23     11  89.59566     10.0        10.0
# ...           ...  ...        ...   ...    ...       ...      ...         ...
# 68940  2017-11-16   16        -70    16     11  89.59566    360.0        20.0
# 68941  2017-11-16   16        -70    17     11  89.59566    360.0        20.0
# 68942  2017-11-16   16        -71    18     11  89.59566     20.0        10.0
# 68943  2017-11-16   16        -70    19     11  89.59566    360.0        30.0
# 68944  2017-11-16   16        -70    20     11  89.59566    330.0        40.0
# 68945  2017-11-16   16        -97    21     11  89.59566     20.0        20.0
# 68946  2017-11-16   16        -80    22     11  89.59566    340.0        50.0
# 68947  2017-11-16   16       -110    23     11  89.59566    320.0        60.0
# 68948  2017-11-17   17       -150     0     11  89.59566    360.0        60.0
# 68949  2017-11-17   17       -150     1     11  89.59566    330.0       100.0
# 68950  2017-11-17   17       -170     2     11  89.59566    330.0       110.0
# 68951  2017-11-17   17       -152     3     11  89.59566    360.0        70.0
# 68952  2017-11-17   17       -180     4     11  89.59566    320.0       110.0
# 68953  2017-11-17   17       -190     5     11  89.59566    320.0        90.0
# 68954  2017-11-17   17       -185     6     11  89.59566    360.0        40.0
# 68955  2017-11-17   17       -190     7     11  89.59566    330.0        90.0
# 68956  2017-11-17   17       -220     8     11  89.59566    340.0        90.0
# 68957  2017-11-17   17       -224     9     11  89.59566    360.0        30.0
# 68958  2017-11-17   17       -220    10     11  89.59566    330.0        90.0
# 68959  2017-11-17   17       -230    11     11  89.59566    330.0       100.0
# 68960  2017-11-17   17       -249    12     11  89.59566    360.0        40.0
# 68961  2017-11-17   17       -220    13     11  89.59566    320.0        80.0
# 68962  2017-11-17   17       -220    14     11  89.59566    320.0        90.0
# 68963  2017-11-17   17       -242    15     11  89.59566    360.0        20.0
# 68964  2017-11-17   17       -220    16     11  89.59566    320.0       100.0
# 68965  2017-11-17   17       -220    17     11  89.59566    330.0       110.0
# 68966  2017-11-17   17       -232    18     11  89.59566    360.0        40.0
# 68967  2017-11-17   17       -210    19     11  89.59566    310.0        50.0
# 68968  2017-11-17   17       -200    20     11  89.59566    310.0        80.0
# 68969  2017-11-17   17       -233    21     11  89.59566    320.0        20.0
#
#        year
# 68870  2017
# 68871  2017
# 68872  2017
# 68873  2017
# 68874  2017
# 68875  2017
# 68876  2017
# 68877  2017
# 68878  2017
# 68879  2017
# 68880  2017
# 68881  2017
# 68882  2017
# 68883  2017
# 68884  2017
# 68885  2017
# 68886  2017
# 68887  2017
# 68888  2017
# 68889  2017
# 68890  2017
# 68891  2017
# 68892  2017
# 68893  2017
# 68894  2017
# 68895  2017
# 68896  2017
# 68897  2017
# 68898  2017
# 68899  2017
# ...     ...
# 68940  2017
# 68941  2017
# 68942  2017
# 68943  2017
# 68944  2017
# 68945  2017
# 68946  2017
# 68947  2017
# 68948  2017
# 68949  2017
# 68950  2017
# 68951  2017
# 68952  2017
# 68953  2017
# 68954  2017
# 68955  2017
# 68956  2017
# 68957  2017
# 68958  2017
# 68959  2017
# 68960  2017
# 68961  2017
# 68962  2017
# 68963  2017
# 68964  2017
# 68965  2017
# 68966  2017
# 68967  2017
# 68968  2017
# 68969  2017
#
# [100 rows x 13 columns]

# %%
pollution_2010_2014
# Out:
#        pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# 24         129.0  -16  -4.0  1020.0      SE     1.79     0     0
# 25         148.0  -15  -4.0  1020.0      SE     2.68     0     0
# 26         159.0  -11  -5.0  1021.0      SE     3.57     0     0
# 27         181.0   -7  -5.0  1022.0      SE     5.36     1     0
# 28         138.0   -7  -5.0  1022.0      SE     6.25     2     0
# 29         109.0   -7  -6.0  1022.0      SE     7.14     3     0
# 30         105.0   -7  -6.0  1023.0      SE     8.93     4     0
# 31         124.0   -7  -5.0  1024.0      SE    10.72     0     0
# 32         120.0   -8  -6.0  1024.0      SE    12.51     0     0
# 33         132.0   -7  -5.0  1025.0      SE    14.30     0     0
# 34         140.0   -7  -5.0  1026.0      SE    17.43     1     0
# 35         152.0   -8  -5.0  1026.0      SE    20.56     0     0
# 36         148.0   -8  -5.0  1026.0      SE    23.69     0     0
# 37         164.0   -8  -5.0  1025.0      SE    27.71     0     0
# 38         158.0   -9  -5.0  1025.0      SE    31.73     0     0
# 39         154.0   -9  -5.0  1025.0      SE    35.75     0     0
# 40         159.0   -9  -5.0  1026.0      SE    37.54     0     0
# 41         164.0   -8  -5.0  1027.0      SE    39.33     0     0
# 42         170.0   -8  -5.0  1027.0      SE    42.46     0     0
# 43         149.0   -8  -5.0  1028.0      SE    44.25     0     0
# 44         154.0   -7  -5.0  1028.0      SE    46.04     0     0
# 45         164.0   -7  -5.0  1027.0      SE    49.17     1     0
# 46         156.0   -8  -6.0  1028.0      SE    52.30     2     0
# 47         126.0   -8  -6.0  1027.0      SE    55.43     3     0
# 48          90.0   -7  -6.0  1027.0      SE    58.56     4     0
# 49          63.0   -8  -6.0  1026.0      SE    61.69     5     0
# 50          65.0   -8  -7.0  1026.0      SE    65.71     6     0
# 51          55.0   -8  -7.0  1025.0      SE    68.84     7     0
# 52          65.0   -8  -7.0  1024.0      SE    72.86     8     0
# 53          83.0   -9  -8.0  1024.0      SE    76.88     9     0
# ...          ...  ...   ...     ...     ...      ...   ...   ...
# 43794       79.0  -13   2.0  1020.0      NE     3.58     0     0
# 43795       35.0   -8   6.0  1021.0      NW     5.81     0     0
# 43796       26.0  -11   5.0  1022.0      NW    12.96     0     0
# 43797       20.0  -12   4.0  1023.0      NW    21.90     0     0
# 43798        8.0  -21   2.0  1025.0      NW    31.73     0     0
# 43799       16.0  -22   0.0  1026.0      NW    38.88     0     0
# 43800       10.0  -19  -1.0  1027.0      NW    51.84     0     0
# 43801       11.0  -18  -1.0  1028.0      NW    61.67     0     0
# 43802       20.0  -17  -1.0  1028.0      NW    70.61     0     0
# 43803        9.0  -17  -1.0  1029.0      NW    81.79     0     0
# 43804        8.0  -19  -2.0  1030.0      NW    94.75     0     0
# 43805        9.0  -21  -3.0  1030.0      NW   109.95     0     0
# 43806        8.0  -23  -4.0  1032.0      NW   130.07     0     0
# 43807        8.0  -22  -5.0  1034.0      NW   143.03     0     0
# 43808        8.0  -22  -5.0  1034.0      NW   150.18     0     0
# 43809        8.0  -22  -3.0  1034.0      NW   155.99     0     0
# 43810        7.0  -22  -2.0  1034.0      NW   163.14     0     0
# 43811       12.0  -22  -2.0  1034.0      NW   170.29     0     0
# 43812       17.0  -22   0.0  1033.0      NW   177.44     0     0
# 43813       11.0  -27   0.0  1032.0      NW   186.38     0     0
# 43814        9.0  -27   1.0  1032.0      NW   196.21     0     0
# 43815       11.0  -26   1.0  1032.0      NW   205.15     0     0
# 43816        8.0  -23   0.0  1032.0      NW   214.09     0     0
# 43817        9.0  -22  -1.0  1033.0      NW   221.24     0     0
# 43818       10.0  -22  -2.0  1033.0      NW   226.16     0     0
# 43819        8.0  -23  -2.0  1034.0      NW   231.97     0     0
# 43820       10.0  -22  -3.0  1034.0      NW   237.78     0     0
# 43821       10.0  -22  -3.0  1034.0      NW   242.70     0     0
# 43822        8.0  -22  -4.0  1034.0      NW   246.72     0     0
# 43823       12.0  -21  -3.0  1034.0      NW   249.85     0     0
#
# [43800 rows x 8 columns]
